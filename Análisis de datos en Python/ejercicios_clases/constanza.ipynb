# %%
import pandas as pd
import numpy as np
import glob
import plotly.express as px
import matplotlib.pyplot as plt
plt.style.use('default')
import warnings
warnings.filterwarnings('ignore')

# %%
data = {
    'Ensayo': ['Ensayo 1', 'Ensayo 2', 'Ensayo 3', 'Ensayo 4', 'Ensayo 5', 'Ensayo 6', 'Ensayo 7'],
    'Buenas': [7, 6, 9, 7, 11, 10, 11],
    'Malas': [6, 3, 1, 7, 1, 3, 4],
    'Omitidas': [2, 6, 5, 1, 4, 2, 0],
    'Total': [15, 15, 15, 15, 15, 15, 15]
}
df = pd.DataFrame(data)
statistics = df.describe()

print("Estadísticas:")
print(statistics)

plt.figure(figsize=(10, 6))
plt.plot(df['Ensayo'], df['Buenas'], marker='o', label='Buenas')
plt.plot(df['Ensayo'], df['Malas'], marker='o', label='Malas')
plt.plot(df['Ensayo'], df['Omitidas'], marker='o', label='Omitidas')
plt.title('Desempeño de Evaluación del Estudiante')
plt.xlabel('Ensayo')
plt.ylabel('Cantidad')
plt.legend()
plt.grid(True)
plt.show()
plt.figure(figsize=(20, 12))
df[['Buenas', 'Malas', 'Omitidas']].boxplot()
plt.title('Distribución de Resultados por Categoría')
plt.ylabel('Cantidad')
plt.grid(True)
plt.show()
# Out:
# Estadísticas:
#           Buenas     Malas  Omitidas  Total
# count   7.000000  7.000000  7.000000    7.0
# mean    8.714286  3.571429  2.857143   15.0
# std     2.058663  2.299068  2.193063    0.0
# min     6.000000  1.000000  0.000000   15.0
# 25%     7.000000  2.000000  1.500000   15.0
# 50%     9.000000  3.000000  2.000000   15.0
# 75%    10.500000  5.000000  4.500000   15.0
# max    11.000000  7.000000  6.000000   15.0

# %%
df
# Out:
#      Ensayo  Buenas  Malas  Omitidas  Total
# 0  Ensayo 1       7      6         2     15
# 1  Ensayo 2       6      3         6     15
# 2  Ensayo 3       9      1         5     15
# 3  Ensayo 4       7      7         1     15
# 4  Ensayo 5      11      1         4     15
# 5  Ensayo 6      10      3         2     15
# 6  Ensayo 7      11      4         0     15
